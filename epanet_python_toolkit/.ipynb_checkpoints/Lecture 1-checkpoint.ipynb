# %% [markdown]
# ### Modelling Water Distribution Networks using EPANET
#
# Introduction to EPANET
# Created in 1993 by Lew Rossman, version 2 in 2000.
# Released in the public domain by the US EPA.
# Designed as a research tool to better understand the dynamics of water quality.
# Solves flows, pressures and water quality for a certain period of time.
# Since v2 it can be linked with external software.
# Links with a graphical interface.
# Extended capabilities with EPANET-MSX
# Now open source from the Open Water Analytics community, Version 2.2
#
# ### Setting up EPANET-Python Toolkit
# How to ask for help: There is an online community, which is actively supported by KIOS. You can ask for comments and help at http://community.wateranalytics.org
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Load EPANET-Python Toolkit

# %%
from epyt import epanet

# %% [markdown]
# ### Load a benchmark network
#
# Decide which benchmark network to use and load the network

# %%
# decide which network to load from the "/networks/" folder  
filename = 'Net1.inp'; # you can also try 'L-TOWN.inp', 'Net3.inp', etc.

# call epanet class and load all data and functions in G structure
G = epanet(filename)
# Out:
# EPANET version 20200 loaded (EPyT version 0.0.1).
# Input File Net1.inp loaded successfully.

# %% [markdown]
# ### How to use the EPANET-MATLAB Toolkit
#
# What data variables are in the class?

# %%
dir(G)
# Out:
# ['BinTempfile',
#  'CMDCODE',
#  'ControlLevelValues',
#  'ControlLinkIndex',
#  'ControlNodeIndex',
#  'ControlRules',
#  'ControlRulesCount',
#  'ControlSettings',
#  'ControlTypes',
#  'ControlTypesIndex',
#  'Controls',
#  'CurveCount',
#  'CurveIndex',
#  'CurvesInfo',
#  'DEMANDMODEL',
#  'DemandModelCode',
#  'DemandModelPexp',
#  'DemandModelPmin',
#  'DemandModelPreq',
#  'DemandModelType',
#  'EnergyEfficiencyUnits',
#  'EnergyUnits',
#  'Errcode',
#  'InputFile',
#  'Iterations',
#  'LOGOP',
#  'LibEPANET',
#  'LibEPANETpath',
#  'LinkBulkReactionCoeff',
#  'LinkCount',
#  'LinkDiameter',
#  'LinkFlowUnits',
#  'LinkFrictionFactorUnits',
#  'LinkIndex',
#  'LinkInitialSetting',
#  'LinkInitialStatus',
#  'LinkLength',
#  'LinkLengthsUnits',
#  'LinkMinorLossCoeff',
#  'LinkMinorLossCoeffUnits',
#  'LinkNameID',
#  'LinkPipeCount',
#  'LinkPipeDiameterUnits',
#  'LinkPipeIndex',
#  'LinkPipeNameID',
#  'LinkPipeRoughnessCoeffUnits',
#  'LinkPumpCount',
# ...

# %% [markdown]
# What methods/functions are in the toolkit?

# %%
vars(G)
# Out:
# {'classversion': '0.0.1',
#  'api': <epyt.epanet.epanetapi at 0x20de1d314f0>,
#  'ToolkitConstants': <epyt.epanet.ToolkitConstants at 0x20de1df7a60>,
#  'InputFile': 'C:\\Users\\eldemet\\Anaconda3\\lib\\site-packages\\epyt\\networks\\asce-tf-wdst\\Net1.inp',
#  '_epanet__exist_inp_file': True,
#  'TempInpFile': 'C:\\Users\\eldemet\\Anaconda3\\lib\\site-packages\\epyt\\networks\\asce-tf-wdst\\Net1_temp.inp',
#  'RptTempfile': 'C:\\Users\\eldemet\\Anaconda3\\lib\\site-packages\\epyt\\networks\\asce-tf-wdst\\Net1_temp.txt',
#  'BinTempfile': 'C:\\Users\\eldemet\\Anaconda3\\lib\\site-packages\\epyt\\networks\\asce-tf-wdst\\Net1_temp.bin',
#  'CMDCODE': 1,
#  'linkInfo': {'LinkDiameter': [18.0,
#    14.0,
#    10.0,
#    10.0,
#    12.0,
#    6.0,
#    18.0,
#    10.0,
#    12.0,
#    8.0,
#    8.0,
#    6.0,
#    0.0],
#   'LinkLength': [10530.0,
#    5280.0,
#    5280.0,
#    5280.0,
#    5280.0,
#    5280.0,
#    200.0,
#    5280.0,
#    5280.0,
#    5280.0,
#    5280.0,
#    5280.0,
# ...

# %% [markdown]
# Getting information from pipes

# %%
G.getLinkPipeCount()
# Out:
# 12

# %%
G.getLinkDiameter()
# Out:
# array([18., 14., 10., 10., 12.,  6., 18., 10., 12.,  8.,  8.,  6.,  0.])
